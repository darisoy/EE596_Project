# %% [markdown]
# <a href="https://colab.research.google.com/github/darisoy/EE596_Final_Project/blob/main/cropper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Assignment: Dogs and Cats Classification with AlexNet

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from zipfile import ZipFile
from PIL import Image
import glob
import shutil

# %%
with ZipFile('/content/drive/MyDrive/furnished.zip', 'r') as zip:
    zip.extractall()

# %%
for image in glob.glob("/content/furnished/*.jpg"):
    img = Image.open(image)
    img = img.crop((0,0,img.size[0],img.size[1]-20))
    img.save(image)

# %%
image = Image.open('/content/furnished/130.jpg')
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=361x260 at 0x7FA450366850>

# %%
shutil.make_archive('/content/drive/MyDrive/furnished_cropped', 'zip', '/content/furnished')
# Out:
# '/content/drive/MyDrive/furnished_cropped.zip'
